# %% [markdown]
# # Exercícios do Minicurso
#
# ## Quadro-resumo dos exercícios
#
# | Notebook               | Título do Exercício                                    | Objetivo Didático                                                                 |
# |------------------------|--------------------------------------------------------|-----------------------------------------------------------------------------------|
# | `basico.ipynb`         | Municípios prioritários para políticas públicas        | Filtrar e ordenar municípios com base em renda e número de famílias               |
# | `joins.ipynb`          | Infos Municípios prioritários para políticas públicas  | Adicionar as informações do município                                             |
# | `with_clause.ipynb`    | Mapeamento de famílias vulneráveis por município       | Cruzar tabelas e agregar famílias por município e perfil de instrução e renda     |
# | `window_functions.ipynb` | Desigualdade de renda dentro das regiões             | Usar funções de janela para classificar as regiões por desilgualdade              |
#
# ---
#
# ## Detalhamento dos exercícios
#
# ### `basico.ipynb` – Municípios prioritários para políticas públicas
#
# Liste os **10 municípios** onde:
# - a **renda média familiar** é inferior a R$ 200, e
# - há mais de 50 famílias cadastradas.
#
# Mostre:
# - `cd_ibge`, `renda_media`, `total_familias`
# Ordene do menor para o maior valor médio de renda.
#
# ---
#
# ### `joins.ipynb` – Infos Municípios prioritários para políticas públicas
#
# Liste os **10 municípios** onde:
# - a **renda média familiar** é inferior a R$ 200, e
# - há mais de 50 famílias cadastradas.
# - utilize a tabela de informações municípios do IBGE
#
# Mostre:
# - `municipio`, `uf`, `regiao`, `total_familias_em_risco`
# Ordene do menor para o maior valor médio de renda.
#
# ---
#
# ### `with_clause.ipynb` – Mapeamento de famílias vulneráveis por município
#
# Liste os **10 municípios** com o maior número de famílias que:
# - possuem **renda média familiar inferior a R$ 200**, e
# - têm **ao menos uma pessoa sem instrução formal** (`cod_curso_frequentou_pessoa_memb`).
#
# Mostre:
# - `municipio`, `uf`, `regiao`, `total_familias`
# Ordene pelo maior número de famílias em risco.
#
# ---
#
# ### `window_functions.ipynb` – Desigualdade de renda dentro das regiões
#
# Calcule a média de renda das famílias por região
# - 10% que recebem menos
# - 10% que recebem mais
# - diferença entre as médias
#
# Mostre:
# - `regiao`, `b_10`, `t_10`, `desigualdade`
# Ordene pela maior desigualdade.

# %% [markdown]
# # Resolução

# %%
from common import DatabaseConnection

conn = DatabaseConnection("database.duckdb")
# Out:
# 2025-06-26 23:41:10,624 - INFO - Connected to database: database.duckdb

# %%
conn.execute("""
    SELECT
        *
    FROM familias
    LIMIT 10;
""")
# Out:
# 2025-06-26 23:41:12,615 - INFO - Executing query...
# 2025-06-26 23:41:12,626 - ERROR - Error executing query
# Traceback (most recent call last):
#   File "/workspaces/minicurso_ciencia_de_dados/common/database.py", line 25, in execute
#     with duckdb.connect(self.database) as conn:
#          ~~~~~~~~~~~~~~^^^^^^^^^^^^^^^
#   File "/workspaces/minicurso_ciencia_de_dados/common/database.py", line 31, in execute
#     result = conn.execute(query).df()
#              ~~~~~~~~~~~~^^^^^^^
# duckdb.duckdb.CatalogException: Catalog Error: Table with name familias does not exist!
# Did you mean "sqlite_master"?
#
# LINE 4:     FROM familias
#                  ^

# %%
conn.execute("""
    SELECT
        *
    FROM pessoas
    LIMIT 10;
""")
# Out:
# 2025-06-26 23:38:59,017 - INFO - Executing query...
# 2025-06-26 23:38:59,029 - ERROR - Error executing query
# Traceback (most recent call last):
#   File "/workspaces/minicurso_ciencia_de_dados/common/database.py", line 25, in execute
#     with duckdb.connect(self.database) as conn:
#          ~~~~~~~~~~~~~~^^^^^^^^^^^^^^^
#   File "/workspaces/minicurso_ciencia_de_dados/common/database.py", line 31, in execute
#     result = conn.execute(query).df()
#              ~~~~~~~~~~~~^^^^^^^
# duckdb.duckdb.CatalogException: Catalog Error: Table with name pessoas does not exist!
# Did you mean "pg_class"?
#
# LINE 4:     FROM pessoas
#                  ^

# %%
conn.execute("""
    SELECT
        *
    FROM ibge_municipios
    LIMIT 10;
""")
# Out:
# 2025-06-26 23:39:01,870 - INFO - Executing query...
# 2025-06-26 23:39:01,874 - INFO - Query executed successfully
#    municipio-id         municipio-nome  microrregiao-id  microrregiao-nome  \
# 0       1100015  Alta Floresta D'Oeste            11006             Cacoal
# 1       1100023              Ariquemes            11003          Ariquemes
# 2       1100031                 Cabixi            11008  Colorado do Oeste
# 3       1100049                 Cacoal            11006             Cacoal
# 4       1100056             Cerejeiras            11008  Colorado do Oeste
# 5       1100064      Colorado do Oeste            11008  Colorado do Oeste
# 6       1100072             Corumbiara            11008  Colorado do Oeste
# 7       1100080          Costa Marques            11002      Guajará-Mirim
# 8       1100098        Espigão D'Oeste            11006             Cacoal
# 9       1100106          Guajará-Mirim            11002      Guajará-Mirim
#
#    mesorregiao-id   mesorregiao-nome  regiao-imediata-id regiao-imediata-nome  \
# 0            1102  Leste Rondoniense              110005               Cacoal
# 1            1102  Leste Rondoniense              110002            Ariquemes
# 2            1102  Leste Rondoniense              110006              Vilhena
# 3            1102  Leste Rondoniense              110005               Cacoal
# 4            1102  Leste Rondoniense              110006              Vilhena
# 5            1102  Leste Rondoniense              110006              Vilhena
# 6            1102  Leste Rondoniense              110006              Vilhena
# 7            1101    Madeira-Guaporé              110004            Ji-Paraná
# 8            1102  Leste Rondoniense              110005               Cacoal
# 9            1101    Madeira-Guaporé              110001          Porto Velho
#
#    regiao-intermediaria-id regiao-intermediaria-nome  UF-id UF-sigla  \
# 0                     1102                 Ji-Paraná     11       RO
# 1                     1101               Porto Velho     11       RO
# 2                     1102                 Ji-Paraná     11       RO
# 3                     1102                 Ji-Paraná     11       RO
# 4                     1102                 Ji-Paraná     11       RO
# 5                     1102                 Ji-Paraná     11       RO
# 6                     1102                 Ji-Paraná     11       RO
# 7                     1102                 Ji-Paraná     11       RO
# 8                     1102                 Ji-Paraná     11       RO
# 9                     1101               Porto Velho     11       RO
#
#     UF-nome  regiao-id regiao-sigla regiao-nome
# 0  Rondônia          1            N       Norte
# 1  Rondônia          1            N       Norte
# 2  Rondônia          1            N       Norte
# 3  Rondônia          1            N       Norte
# 4  Rondônia          1            N       Norte
# 5  Rondônia          1            N       Norte
# 6  Rondônia          1            N       Norte
# 7  Rondônia          1            N       Norte
# 8  Rondônia          1            N       Norte
# 9  Rondônia          1            N       Norte

# %%
display (conn.execute ("""
    SELECT 
      CD_IBGE,
      ROUND(AVG(VLR_RENDA_MEDIA_FAM), 2) AS RENDA_MEDIA)
      COUNT (*) AS TOTAL_FAMILIA_
    FROM FAMILIA 
    GROUP BY CD_IBGE
    HAVING TOTAL_FAMILIA > 50 AND RENDA_MEDIA <200 
    ORDER BY RENDA
